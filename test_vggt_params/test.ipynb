# %%
import numpy as np

# %%
fo = np.load("kps/fo.npy")
dtl = np.load("kps/dtl.npy")
rear = np.load("kps/rear.npy")

fo = fo[:1952, :, :]
dtl = dtl[:1952, :, :]

# %%
fo.shape, dtl.shape, rear.shape
# Out:
# ((1952, 17, 3), (1952, 17, 3), (1952, 17, 3))

# %%
all_kps = np.stack((fo, dtl, rear), axis = 1)

keypoints = all_kps[..., :2]
confideces = all_kps[..., 2]

keypoints.shape, confideces.shape
# Out:
# ((1952, 3, 17, 2), (1952, 3, 17))

# %%
frame_ids = np.linspace(0, 1951, 200).astype(int)

frame_ids
# Out:
# array([   0,    9,   19,   29,   39,   49,   58,   68,   78,   88,   98,
#         107,  117,  127,  137,  147,  156,  166,  176,  186,  196,  205,
#         215,  225,  235,  245,  254,  264,  274,  284,  294,  303,  313,
#         323,  333,  343,  352,  362,  372,  382,  392,  401,  411,  421,
#         431,  441,  450,  460,  470,  480,  490,  500,  509,  519,  529,
#         539,  549,  558,  568,  578,  588,  598,  607,  617,  627,  637,
#         647,  656,  666,  676,  686,  696,  705,  715,  725,  735,  745,
#         754,  764,  774,  784,  794,  803,  813,  823,  833,  843,  852,
#         862,  872,  882,  892,  901,  911,  921,  931,  941,  950,  960,
#         970,  980,  990, 1000, 1009, 1019, 1029, 1039, 1049, 1058, 1068,
#        1078, 1088, 1098, 1107, 1117, 1127, 1137, 1147, 1156, 1166, 1176,
#        1186, 1196, 1205, 1215, 1225, 1235, 1245, 1254, 1264, 1274, 1284,
#        1294, 1303, 1313, 1323, 1333, 1343, 1352, 1362, 1372, 1382, 1392,
# ...
